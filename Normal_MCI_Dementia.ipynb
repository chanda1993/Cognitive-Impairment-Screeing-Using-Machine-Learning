# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### row = record
# ### column = attribute / dimension
# ### target = prediction

# %%
Tests_df = pd.read_csv('normal_mci_dementia.csv')

# %%
Tests_df.head()
# Out:
#     Edu  Age  Digit_span_Forward  Digit_span_Backward  Letter_cancellation  \
# 0   3.0   50                   4                    2                    3
# 1   6.0   50                   8                    4                    3
# 2   6.0   50                   6                    3                    3
# 3  16.0   50                   9                    7                    3
# 4   9.0   50                   6                    4                    3
#
#    Spontaneous_speech_fluency  Spontaneous_speech_contents  Comprehension  \
# 0                           3                            3              3
# 1                           3                            3              3
# 2                           3                            3              3
# 3                           3                            3              3
# 4                           3                            3              3
#
#    Naming_K_BNT  Finger_naming  ...  StroopTest_Colorreading_correct  \
# 0            45              3  ...                               89
# 1            51              3  ...                              100
# 2            51              3  ...                               78
# 3            51              3  ...                              112
# 4            52              3  ...                               81
#
#    StroopTest_Colorreading_error  K_MMSE_orientation_to_time  \
# 0                              1                           5
# 1                              0                           5
# 2                              1                           5
# 3                              0                           5
# 4                              2                           3
#
#    K_MMSE_orientation_to_place  K_MMSE_Registation  \
# 0                            5                   3
# 1                            5                   3
# 2                            5                   3
# 3                            5                   3
# 4                            3                   3
#
#    K_MMSE_attention_and_calculation  K_MMSE_recall  K_MMSE_language  \
# 0                                 4              3                6
# 1                                 5              3                7
# 2                                 3              2                8
# 3                                 5              3                8
# 4                                 3              1                7
#
#    K_MMSE_drawing  Dx
# 0               1   0
# 1               1   0
# 2               1   0
# 3               1   1
# 4               1   1
#
# [5 rows x 47 columns]

# %%
Tests_df.tail()
# Out:
#         Edu  Age  Digit_span_Forward  Digit_span_Backward  \
# 14921  18.0   80                   6                    4
# 14922  18.0   80                   6                    4
# 14923  18.0   80                  18                    4
# 14924  18.0   80                  18                    3
# 14925  18.0   80                   6                    4
#
#        Letter_cancellation  Spontaneous_speech_fluency  \
# 14921                    3                           3
# 14922                    3                           3
# 14923                    3                           3
# 14924                    3                           3
# 14925                    3                           3
#
#        Spontaneous_speech_contents  Comprehension  Naming_K_BNT  \
# 14921                            3              3            47
# 14922                            3              3            47
# 14923                            3              3            47
# 14924                            3              3            47
# 14925                            3              3            47
#
#        Finger_naming  ...  StroopTest_Colorreading_correct  \
# 14921              3  ...                               82
# 14922              3  ...                               82
# 14923              3  ...                               82
# 14924              3  ...                               82
# 14925              3  ...                               82
#
#        StroopTest_Colorreading_error  K_MMSE_orientation_to_time  \
# 14921                              0                           5
# 14922                              0                           5
# 14923                              0                           5
# 14924                              0                           5
# 14925                              0                           5
#
#        K_MMSE_orientation_to_place  K_MMSE_Registation  \
# 14921                            5                   3
# 14922                            5                   3
# 14923                            5                   3
# 14924                            5                   3
# 14925                            5                   3
#
#        K_MMSE_attention_and_calculation  K_MMSE_recall  K_MMSE_language  \
# 14921                                 5              3                8
# 14922                                 5              3                8
# 14923                                 5              3                8
# 14924                                 4              0                7
# 14925                                 5              3                8
#
#        K_MMSE_drawing  Dx
# 14921               1   0
# 14922               1   0
# 14923               1   0
# 14924               1   0
# 14925               1   0
#
# [5 rows x 47 columns]

# %%
Tests_df.shape
# Out:
# (14926, 47)

# %%
Tests_df.size
# Out:
# 701522

# %%
Tests_df.count()
# Out:
# Edu                                        14926
# Age                                        14926
# Digit_span_Forward                         14926
# Digit_span_Backward                        14926
# Letter_cancellation                        14926
# Spontaneous_speech_fluency                 14926
# Spontaneous_speech_contents                14926
# Comprehension                              14926
# Naming_K_BNT                               14926
# Finger_naming                              14926
# Right_left_orientation                     14926
# Body_part_identification                   14926
# Praxis_Ideomotor                           14926
# Praxis_buccofacial                         14926
# Calculation_total_score                    14926
# Rey_CFT_copy_score                         14926
# Rey_CFT_copy_time                          14926
# SVLT_recall_trial1                         14926
# SVLT_recall_trial2                         14926
# SVLT_recall_trial3                         14926
# SVLT_recall                                14926
# SVLT_Delayed_recall                        14926
# SVLT_recognition_discriminability_index    14926
# RCFT_immediate_recall                      14926
# RCFT_delayed_recall                        14926
# RCFT_recognition_discriminability_index    14926
# Motor_impersistence                        14926
# Contrasting_program                        14926
# Go_No_Go                                   14926
# Alternating_hand_movement                  14926
# Alternating_square_and_triangle            14926
# Luria_loop                                 14926
# COWAT_animal                               14926
# COWAT_supermarket                          14926
# COWAT_phonemic_total_score                 14926
# StroopTest_Wordreading_correct             14926
# StroopTest_Wordreading_error               14926
# StroopTest_Colorreading_correct            14926
# StroopTest_Colorreading_error              14926
# K_MMSE_orientation_to_time                 14926
# K_MMSE_orientation_to_place                14926
# K_MMSE_Registation                         14926
# K_MMSE_attention_and_calculation           14926
# K_MMSE_recall                              14926
# K_MMSE_language                            14926
# K_MMSE_drawing                             14926
# Dx                                         14926
# dtype: int64

# %%
Tests_df['Dx'].value_counts()
# Out:
# 1    6002
# 2    5707
# 0    3217
# Name: Dx, dtype: int64

# %%
#Distribution of the classes
normal_df = Tests_df[Tests_df['Dx']==0] [0:200]
mci_df = Tests_df[Tests_df['Dx']==1] [0:200]
dementia_df = Tests_df[Tests_df['Dx']==2] [0:200]

axes = normal_df.plot(kind= 'scatter', x = 'Age', y = 'Digit_span_Forward', color ='blue', label = 'Normal')

mci_df.plot(kind= 'scatter', x = 'Age', y = 'Digit_span_Forward', color ='red', label = 'MCI', ax = axes)

dementia_df.plot(kind= 'scatter', x = 'Age', y = 'Digit_span_Forward', color ='black', label = 'Dementia', ax = axes)

# %%
#Identifying unwated rows

Tests_df.dtypes
# Out:
# Edu                                        float64
# Age                                          int64
# Digit_span_Forward                           int64
# Digit_span_Backward                          int64
# Letter_cancellation                          int64
# Spontaneous_speech_fluency                   int64
# Spontaneous_speech_contents                  int64
# Comprehension                                int64
# Naming_K_BNT                                 int64
# Finger_naming                                int64
# Right_left_orientation                       int64
# Body_part_identification                     int64
# Praxis_Ideomotor                             int64
# Praxis_buccofacial                           int64
# Calculation_total_score                      int64
# Rey_CFT_copy_score                         float64
# Rey_CFT_copy_time                            int64
# SVLT_recall_trial1                           int64
# SVLT_recall_trial2                           int64
# SVLT_recall_trial3                           int64
# SVLT_recall                                  int64
# SVLT_Delayed_recall                          int64
# SVLT_recognition_discriminability_index    float64
# RCFT_immediate_recall                      float64
# RCFT_delayed_recall                        float64
# RCFT_recognition_discriminability_index    float64
# Motor_impersistence                          int64
# Contrasting_program                          int64
# Go_No_Go                                     int64
# Alternating_hand_movement                    int64
# Alternating_square_and_triangle              int64
# Luria_loop                                   int64
# COWAT_animal                                 int64
# COWAT_supermarket                            int64
# COWAT_phonemic_total_score                   int64
# StroopTest_Wordreading_correct               int64
# StroopTest_Wordreading_error                 int64
# StroopTest_Colorreading_correct              int64
# StroopTest_Colorreading_error                int64
# K_MMSE_orientation_to_time                   int64
# K_MMSE_orientation_to_place                  int64
# K_MMSE_Registation                           int64
# K_MMSE_attention_and_calculation             int64
# K_MMSE_recall                                int64
# K_MMSE_language                              int64
# K_MMSE_drawing                               int64
# Dx                                           int64
# dtype: object

# %%
Tests_df = Tests_df[pd.to_numeric (Tests_df['Edu'], errors = 'coerce').notnull()]
Tests_df['Edu'] = Tests_df['Edu'].astype('int')

# %%
Tests_df = Tests_df[pd.to_numeric (Tests_df['Rey_CFT_copy_score'], errors = 'coerce').notnull()]
Tests_df['Rey_CFT_copy_score'] = Tests_df['Rey_CFT_copy_score'].astype('int')

# %%
Tests_df = Tests_df[pd.to_numeric (Tests_df['SVLT_recognition_discriminability_index'], errors = 'coerce').notnull()]
Tests_df['SVLT_recognition_discriminability_index'] = Tests_df['SVLT_recognition_discriminability_index'].astype('int')

# %%
Tests_df = Tests_df[pd.to_numeric (Tests_df['RCFT_immediate_recall'], errors = 'coerce').notnull()]
Tests_df['RCFT_immediate_recall'] = Tests_df['RCFT_immediate_recall'].astype('int')

# %%
Tests_df = Tests_df[pd.to_numeric (Tests_df['RCFT_delayed_recall'], errors = 'coerce').notnull()]
Tests_df['RCFT_delayed_recall'] = Tests_df['RCFT_delayed_recall'].astype('int')

# %%
Tests_df = Tests_df[pd.to_numeric (Tests_df['RCFT_recognition_discriminability_index'], errors = 'coerce').notnull()]
Tests_df['RCFT_recognition_discriminability_index'] = Tests_df['RCFT_recognition_discriminability_index'].astype('int')
Tests_df.dtypes
# Out:
# Edu                                        int32
# Age                                        int64
# Digit_span_Forward                         int64
# Digit_span_Backward                        int64
# Letter_cancellation                        int64
# Spontaneous_speech_fluency                 int64
# Spontaneous_speech_contents                int64
# Comprehension                              int64
# Naming_K_BNT                               int64
# Finger_naming                              int64
# Right_left_orientation                     int64
# Body_part_identification                   int64
# Praxis_Ideomotor                           int64
# Praxis_buccofacial                         int64
# Calculation_total_score                    int64
# Rey_CFT_copy_score                         int32
# Rey_CFT_copy_time                          int64
# SVLT_recall_trial1                         int64
# SVLT_recall_trial2                         int64
# SVLT_recall_trial3                         int64
# SVLT_recall                                int64
# SVLT_Delayed_recall                        int64
# SVLT_recognition_discriminability_index    int32
# RCFT_immediate_recall                      int32
# RCFT_delayed_recall                        int32
# RCFT_recognition_discriminability_index    int32
# Motor_impersistence                        int64
# Contrasting_program                        int64
# Go_No_Go                                   int64
# Alternating_hand_movement                  int64
# Alternating_square_and_triangle            int64
# Luria_loop                                 int64
# COWAT_animal                               int64
# COWAT_supermarket                          int64
# COWAT_phonemic_total_score                 int64
# StroopTest_Wordreading_correct             int64
# StroopTest_Wordreading_error               int64
# StroopTest_Colorreading_correct            int64
# StroopTest_Colorreading_error              int64
# K_MMSE_orientation_to_time                 int64
# K_MMSE_orientation_to_place                int64
# K_MMSE_Registation                         int64
# K_MMSE_attention_and_calculation           int64
# K_MMSE_recall                              int64
# K_MMSE_language                            int64
# K_MMSE_drawing                             int64
# Dx                                         int64
# dtype: object

# %%
#Remove unwanted columns

Tests_df.columns
# Out:
# Index(['Edu', 'Age', 'Digit_span_Forward', 'Digit_span_Backward',
#        'Letter_cancellation', 'Spontaneous_speech_fluency',
#        'Spontaneous_speech_contents', 'Comprehension', 'Naming_K_BNT',
#        'Finger_naming', 'Right_left_orientation', 'Body_part_identification',
#        'Praxis_Ideomotor', 'Praxis_buccofacial', 'Calculation_total_score',
#        'Rey_CFT_copy_score', 'Rey_CFT_copy_time', 'SVLT_recall_trial1',
#        'SVLT_recall_trial2', 'SVLT_recall_trial3', 'SVLT_recall',
#        'SVLT_Delayed_recall', 'SVLT_recognition_discriminability_index',
#        'RCFT_immediate_recall', 'RCFT_delayed_recall',
#        'RCFT_recognition_discriminability_index', 'Motor_impersistence',
#        'Contrasting_program', 'Go_No_Go', 'Alternating_hand_movement',
#        'Alternating_square_and_triangle', 'Luria_loop', 'COWAT_animal',
#        'COWAT_supermarket', 'COWAT_phonemic_total_score',
#        'StroopTest_Wordreading_correct', 'StroopTest_Wordreading_error',
#        'StroopTest_Colorreading_correct', 'StroopTest_Colorreading_error',
#        'K_MMSE_orientation_to_time', 'K_MMSE_orientation_to_place',
#        'K_MMSE_Registation', 'K_MMSE_attention_and_calculation',
#        'K_MMSE_recall', 'K_MMSE_language', 'K_MMSE_drawing', 'Dx'],
#       dtype='object')

# %%
Tests_df.head()
# Out:
#    Edu  Age  Digit_span_Forward  Digit_span_Backward  Letter_cancellation  \
# 0    3   50                   4                    2                    3
# 1    6   50                   8                    4                    3
# 2    6   50                   6                    3                    3
# 3   16   50                   9                    7                    3
# 4    9   50                   6                    4                    3
#
#    Spontaneous_speech_fluency  Spontaneous_speech_contents  Comprehension  \
# 0                           3                            3              3
# 1                           3                            3              3
# 2                           3                            3              3
# 3                           3                            3              3
# 4                           3                            3              3
#
#    Naming_K_BNT  Finger_naming  ...  StroopTest_Colorreading_correct  \
# 0            45              3  ...                               89
# 1            51              3  ...                              100
# 2            51              3  ...                               78
# 3            51              3  ...                              112
# 4            52              3  ...                               81
#
#    StroopTest_Colorreading_error  K_MMSE_orientation_to_time  \
# 0                              1                           5
# 1                              0                           5
# 2                              1                           5
# 3                              0                           5
# 4                              2                           3
#
#    K_MMSE_orientation_to_place  K_MMSE_Registation  \
# 0                            5                   3
# 1                            5                   3
# 2                            5                   3
# 3                            5                   3
# 4                            3                   3
#
#    K_MMSE_attention_and_calculation  K_MMSE_recall  K_MMSE_language  \
# 0                                 4              3                6
# 1                                 5              3                7
# 2                                 3              2                8
# 3                                 5              3                8
# 4                                 3              1                7
#
#    K_MMSE_drawing  Dx
# 0               1   0
# 1               1   0
# 2               1   0
# 3               1   1
# 4               1   1
#
# [5 rows x 47 columns]

# %%
feature_df = Tests_df[['Edu', 'Age', 'Digit_span_Forward', 'Digit_span_Backward',
       'Letter_cancellation', 'Spontaneous_speech_fluency',
       'Spontaneous_speech_contents', 'Comprehension', 'Naming_K_BNT',
       'Finger_naming', 'Right_left_orientation', 'Body_part_identification',
       'Praxis_Ideomotor', 'Praxis_buccofacial', 'Calculation_total_score',
       'Rey_CFT_copy_score', 'Rey_CFT_copy_time', 'SVLT_recall_trial1',
       'SVLT_recall_trial2', 'SVLT_recall_trial3', 'SVLT_recall',
       'SVLT_Delayed_recall', 'SVLT_recognition_discriminability_index',
       'RCFT_immediate_recall', 'RCFT_delayed_recall',
       'RCFT_recognition_discriminability_index', 'Motor_impersistence',
       'Contrasting_program', 'Go_No_Go', 'Alternating_hand_movement',
       'Alternating_square_and_triangle', 'Luria_loop', 'COWAT_animal',
       'COWAT_supermarket', 'COWAT_phonemic_total_score',
       'StroopTest_Wordreading_correct', 'StroopTest_Wordreading_error',
       'StroopTest_Colorreading_correct', 'StroopTest_Colorreading_error',
       'K_MMSE_orientation_to_time', 'K_MMSE_orientation_to_place',
       'K_MMSE_Registation', 'K_MMSE_attention_and_calculation',
       'K_MMSE_recall', 'K_MMSE_language', 'K_MMSE_drawing']]

# %%
# cell_df 100 rows and 11 columns,
#picked 9 columns out of 11

#Independent var
X = np.asarray (feature_df)

# dependet variable
Y= np.asarray (Tests_df['Dx'])

Y[0:5]
# Out:
# array([0, 0, 0, 1, 1], dtype=int64)

# %%
# Divide the date as Train/Test dataset
'''
    cell_df (100) --> Train (80 rows) / Test (20 rows)
    
    Train(X, Y) ## x itself is 2D array.  ## y is 1D
    Test (X, Y)
'''

from sklearn.model_selection import train_test_split


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=4)

#11940*44
X_train.shape

#11940*1
Y_train.shape

#2986*44
X_test.shape

#2986*1
Y_test.shape
# Out:
# (2986,)

# %%
#Modeling (SVM with Scikit-learn)

from sklearn import svm 

classifier = svm.SVC(kernel='linear', gamma='auto', C=2)
classifier.fit(X_train, Y_train)

Y_Predict = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print ('Accuracy Score Normal vs MCI vs Dementia: ', accuracy_score(Y_test, Y_Predict))
# Out:
# Accuracy Score Normal vs MCI vs Dementia:  0.8385800401875418

# %%
from sklearn.metrics import classification_report

pd.DataFrame(classification_report(Y_test, 
                            Y_Predict, 
                            output_dict=True))
# Out:
#                     0            1            2  accuracy    macro avg  \
# precision    0.803709     0.809332     0.892336   0.83858     0.835126
# recall       0.844156     0.818552     0.857143   0.83858     0.839950
# f1-score     0.823436     0.813916     0.874385   0.83858     0.837246
# support    616.000000  1229.000000  1141.000000   0.83858  2986.000000
#
#            weighted avg
# precision      0.839889
# recall         0.838580
# f1-score       0.838986
# support     2986.000000

# %%
from sklearn import metrics
import scikitplot as skplt

skplt.metrics.plot_confusion_matrix(Y_test, Y_Predict)
plt.show()
